# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 200)

from sklearn.metrics import mean_squared_log_error

from lightgbm import LGBMRegressor
from sklearn.linear_model import LinearRegression

from sklearn.preprocessing import MinMaxScaler, StandardScaler, PowerTransformer

from skopt import gp_minimize

# %% [markdown]
# # Read Data

# %% [markdown]
# ### Oil data

# %%
data = pd.read_csv('../01-Data/DataGas.csv', parse_dates=['Analysis_Date', 'Last_Day_of_Analyses_of_Week'])

# %%
data.head()
# Out:
#    Unnamed:_0 Analysis_Date Last_Day_of_Analyses_of_Week   Macroregion  \
# 0       12064    2004-05-09                   2004-05-15  CENTRO OESTE
# 1       12065    2004-05-09                   2004-05-15  CENTRO OESTE
# 2       12066    2004-05-09                   2004-05-15  CENTRO OESTE
# 3       12067    2004-05-09                   2004-05-15  CENTRO OESTE
# 4       12068    2004-05-09                   2004-05-15      NORDESTE
#
#                 State         Product  No_of_Gas_Stations_Analyzed  \
# 0    DISTRITO FEDERAL  GASOLINA COMUM                          128
# 1               GOIAS  GASOLINA COMUM                          395
# 2         MATO GROSSO  GASOLINA COMUM                          194
# 3  MATO GROSSO DO SUL  GASOLINA COMUM                          166
# 4             ALAGOAS  GASOLINA COMUM                          106
#
#   Measurement_Unit  Mean_Price  Std_Dev  Min_Price  Max_Price  \
# 0             R$/l       2.029    0.007       1.99      2.070
# 1             R$/l       2.025    0.062       1.85      2.220
# 2             R$/l       2.358    0.066       2.00      2.540
# 3             R$/l       2.120    0.075       1.97      2.440
# 4             R$/l       2.090    0.034       2.00      2.159
#
#   Mean_Price_Margin  Coefficient_of_variation Mean_Dist_Price  \
# 0             0.318                     0.003           1.711
# 1             0.296                     0.031           1.729
# 2             0.472                     0.028           1.886
# 3             0.325                     0.035           1.795
# 4              0.35                     0.016            1.74
#
#   Distribution_Std_Dev Distribution_Min_Price Distribution_Max_Price  \
# 0                 0.02                  1.651                 1.7427
# 1                0.036                 1.6643                  1.915
# 2                0.068                   1.75                 2.0713
# 3                0.033                1.70701                 1.9703
# 4                0.042                 1.6789                  1.918
#
#   Distribution_Coefficient_of_Variation  Month  Year
# 0                                 0.012      5  2004
# 1                                 0.021      5  2004
# 2                                 0.036      5  2004
# 3                                 0.018      5  2004
# 4                                 0.024      5  2004

# %%
data.columns
# Out:
# Index(['Unnamed:_0', 'Analysis_Date', 'Last_Day_of_Analyses_of_Week',
#        'Macroregion', 'State', 'Product', 'No_of_Gas_Stations_Analyzed',
#        'Measurement_Unit', 'Mean_Price', 'Std_Dev', 'Min_Price', 'Max_Price',
#        'Mean_Price_Margin', 'Coefficient_of_variation', 'Mean_Dist_Price',
#        'Distribution_Std_Dev', 'Distribution_Min_Price',
#        'Distribution_Max_Price', 'Distribution_Coefficient_of_Variation',
#        'Month', 'Year'],
#       dtype='object')

# %% [markdown]
# ### Economic Data

# %%
economic_data = pd.read_csv('../01-Data/economic_data.csv',  parse_dates=['Date'])

# %%
economic_data.head()
# Out:
#         Date   Oil_mean  Selic_mean  Dollar_mean  Gold_mean  Oil_median  \
# 0 2004-05-09  39.297143        16.0     3.014014  37.064286       39.41
# 1 2004-05-16  40.687143        16.0     3.113114  37.492857       40.94
# 2 2004-05-23  40.867143        16.0     3.158643  38.290000       40.92
# 3 2004-05-30  40.693214        16.0     3.137500  38.778571       40.60
# 4 2004-06-06  39.843214        16.0     3.133371  38.828571       39.29
#
#    Selic_median  Dollar_median  Gold_median   Oil_std  Selic_std  Dollar_std  \
# 0          16.0       2.989100        36.90  0.578179        0.0    0.059211
# 1          16.0       3.113267        37.45  0.943112        0.0    0.011204
# 2          16.0       3.180500        38.30  0.664057        0.0    0.042535
# 3          16.0       3.151600        38.70  0.939225        0.0    0.031106
# 4          16.0       3.129400        38.70  1.591660        0.0    0.012524
#
#    Gold_std
# 0  0.414151
# 1  0.332757
# 2  0.569077
# 3  0.305007
# 4  0.541322

# %%
economic_data.columns
# Out:
# Index(['Date', 'Oil_mean', 'Selic_mean', 'Dollar_mean', 'Gold_mean',
#        'Oil_median', 'Selic_median', 'Dollar_median', 'Gold_median', 'Oil_std',
#        'Selic_std', 'Dollar_std', 'Gold_std'],
#       dtype='object')

# %% [markdown]
# # Join the Economic Data with the oil data

# %%
data = data.merge(economic_data, left_on='Analysis_Date', right_on='Date')

# %% [markdown]
# # Train and Validation Split (Simple Holdout)

# %%
data_train = data[data['Last_Day_of_Analyses_of_Week'] < '2011-01-01']
data_valid = data[data['Last_Day_of_Analyses_of_Week'] >= '2011-01-01']

# %% [markdown]
# # New DataFrame for Train and Validation (Index: original Data)

# %%
df_train = pd.DataFrame(index=data_train.index)
df_valid  = pd.DataFrame(index=data_valid.index)

# %% [markdown]
# # Feature Engineering

# %%
MM_scaler = MinMaxScaler()
SS_scaler = StandardScaler()
pow_trans = PowerTransformer()


dataset_list = [(df_train, data_train), (df_valid, data_valid)]
var_one_hot = ['Macroregion', 'State']
regex = ['_mean', '_median', '_std']

def one_hot_encoding(model_dataset, sample_dataset, var):
    for label in sample_dataset[var].unique():
        model_dataset[var + '_' + label] = np.where(sample_dataset[var] == label, 1, 0)


for dataset in dataset_list:
    
    model_dataset, sample_dataset = dataset
    
    #Target: First Difference of Average Resale Price
    model_dataset['diff_Mean_Price'] = sample_dataset.groupby(['State'])['Mean_Price'].apply(lambda row: row.diff().shift(-1))
    
    ## Features
    # Current Mean Price
    model_dataset['Current_Mean_Price'] = sample_dataset['Mean_Price']
    
    # Mean Price Margin
    sample_dataset['Mean_Price_Margin'] = sample_dataset['Mean_Price_Margin'].astype(str)
    sample_dataset['Mean_Price_Margin'] = sample_dataset['Mean_Price_Margin'].replace('-', 0)
    sample_dataset['Mean_Price_Margin'] = sample_dataset['Mean_Price_Margin'].astype(float)
    model_dataset['Mean_Price_Margin'] = sample_dataset['Mean_Price_Margin'].astype(float)
    
    # Mean Price Margin with lag 1 week
    model_dataset['Mean_Price_Margin_lag_1_week'] = sample_dataset.groupby(['State'])['Mean_Price_Margin'].apply(lambda row: row.diff().shift(1))
    
    # Ratio Mean Price Margin / Mean Price Margin with lag 1 week
    model_dataset['Mean_Price_Margin_ratio'] = model_dataset['Mean_Price_Margin'] / model_dataset['Mean_Price_Margin_lag_1_week']
        
    #Seasonality
    model_dataset['month'] = sample_dataset['Last_Day_of_Analyses_of_Week'].dt.month
    model_dataset['day'] = sample_dataset['Last_Day_of_Analyses_of_Week'].dt.day
    model_dataset['dayofyear'] = sample_dataset['Last_Day_of_Analyses_of_Week'].dt.dayofyear
    model_dataset['year'] = sample_dataset['Last_Day_of_Analyses_of_Week'].dt.year
    #Encoding cyclic features
    columns = ['month', 'day', 'dayofyear', 'year']
    for col in columns:
        model_dataset[col + '_sin'] = np.sin((2*np.pi*model_dataset[col])/max(model_dataset[col]))
        model_dataset[col + '_cos'] = np.cos((2*np.pi*model_dataset[col])/max(model_dataset[col]))
         
    #Movel Average
    model_dataset['Movel_Average_Mean_Price_4_weeks'] = sample_dataset.groupby(['State'])['Mean_Price'].rolling(4).mean().reset_index(level=0, drop=True)
    
    #Economic Columns
    for reg in regex:
        economic_columns = economic_data.filter(regex=reg, axis=1).columns
        for col in economic_columns:
            model_dataset[col] = sample_dataset[col]
            # MinMaxScaler
            MM_scaler.fit(df_train[[col]])
            model_dataset[col + '_MM'] = MM_scaler.transform(model_dataset[[col]])
            # StandardScaler
            SS_scaler.fit(df_train[[col]])
            model_dataset[col + '_SS'] = SS_scaler.transform(model_dataset[[col]])
            # PowerTransformer
            pow_trans.fit(df_train[[col]])
            model_dataset[col + '_PW'] = pow_trans.transform(model_dataset[[col]])
            
    #Ratio Current_Mean_Price / Dollar
    model_dataset['Current_Mean_Price_Dollar_mean_ratio'] = model_dataset['Current_Mean_Price'] / model_dataset['Dollar_mean']
    #Ratio Current_Mean_Price / Oil
    model_dataset['Current_Mean_Price_Oil_mean_ratio'] = model_dataset['Current_Mean_Price'] / model_dataset['Oil_mean']
    
    
    #One Hot Encoding
    for var in var_one_hot:
        one_hot_encoding(model_dataset, sample_dataset, var)

# %% [markdown]
# # Drop Missing Values

# %%
df_train = df_train.dropna()
df_valid = df_valid.dropna()

# %% [markdown]
# # X, y Train and Validation Split

# %%
Xtr, ytr = df_train.drop(['diff_Mean_Price'], axis=1), df_train['diff_Mean_Price']
Xval, yval = df_valid.drop(['diff_Mean_Price'], axis=1), df_valid['diff_Mean_Price']

# %% [markdown]
# ### Model With Some Features and without Encode

# %%
feat_columns = ['Gold_mean', 'Mean_Price_Margin_ratio', 'month_cos', 'Current_Mean_Price_Dollar_mean_ratio']


mdl = LGBMRegressor(num_leaves=2, min_data_in_leaf=250, n_jobs=-1, random_state=0, n_estimators=500)
mdl.fit(Xtr[feat_columns], ytr)
p = mdl.predict(Xval[feat_columns])

p_final = Xval['Current_Mean_Price'] + p
yval_final = Xval['Current_Mean_Price'] + yval

np.sqrt(mean_squared_log_error(yval_final, p_final)) * 100
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=250, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=250
# 0.9793560848165536

# %%
feat_columns = ['Gold_mean', 'Mean_Price_Margin_ratio', 'month_cos', 'Current_Mean_Price_Dollar_mean_ratio']

def treinar_modelo(params):
    learning_rate = params[0]
    num_leaves = params[1]
    min_child_samples = params[2]
    subsample = params[3]
    colsample_bytree = params[4]
    
    print(params, '\n')
    
    mdl = LGBMRegressor(learning_rate=learning_rate, num_leaves=num_leaves, min_child_samples=min_child_samples,
                        subsample=subsample, colsample_bytree=colsample_bytree, random_state=0, subsample_freq=1, 
                         n_estimators=500, n_jobs=-1)
    mdl.fit(Xtr[feat_columns], ytr)
    
    p = mdl.predict(Xval[feat_columns])

    p_final = Xval['Current_Mean_Price'] + p
    yval_final = Xval['Current_Mean_Price'] + yval
    
    return np.sqrt(mean_squared_log_error(yval_final, p_final)) * 100

space = [(1e-3, 1e-1, 'log-uniform'), #learning rate
         (2, 128), # num_leaves
         (1, 50), # min_child_samples
         (0.05, 1.0), # subsample
         (0.1, 1.0)] # colsample bytree


resultados_gp = gp_minimize(treinar_modelo, space, random_state=1, verbose=1, n_calls=50, n_random_starts=10)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# [0.09871192514273254, 120, 7, 0.9990884895579377, 0.3124800792567785]
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 3.6263
# Function value obtained: 1.0076
# Current minimum: 1.0076
# Iteration No: 2 started. Evaluating function at random point.
# [0.006210998932353835, 51, 34, 0.9387621172657304, 0.8616798250174156]
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 2.7975
# Function value obtained: 0.9811
# Current minimum: 0.9811
# Iteration No: 3 started. Evaluating function at random point.
# [0.004232013397179603, 68, 23, 0.2680983530433343, 0.5809725180523154]
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 3.1875
# Function value obtained: 0.9819
# Current minimum: 0.9811
# Iteration No: 4 started. Evaluating function at random point.
# [0.0672858974212934, 60, 22, 0.9421713999524447, 0.8005503127028804]
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 3.1815
# Function value obtained: 1.0526
# Current minimum: 0.9811
# Iteration No: 5 started. Evaluating function at random point.
# [0.027035912483147396, 103, 6, 0.5422449214947946, 0.8785182267810853]
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 4.5837
# Function value obtained: 1.0589
# Current minimum: 0.9811
# Iteration No: 6 started. Evaluating function at random point.
# [0.045529597892867466, 107, 14, 0.1062810412364853, 0.7034752360620511]
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 2.2520
# Function value obtained: 1.0438
# Current minimum: 0.9811
# Iteration No: 7 started. Evaluating function at random point.
# [0.01535080081765723, 87, 21, 0.23767335308554222, 0.3606666764912312]
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 2.3786
# Function value obtained: 0.9847
# Current minimum: 0.9811
# Iteration No: 8 started. Evaluating function at random point.
# [0.0019241559628256106, 101, 21, 0.0824627456265471, 0.661626987829618]
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 1.6558
# Function value obtained: 0.9824
# Current minimum: 0.9811
# Iteration No: 9 started. Evaluating function at random point.
# [0.02095421812724112, 40, 23, 0.2610183201586061, 0.16602775456833962]
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 1.8171
# Function value obtained: 0.9850
# Current minimum: 0.9811
# Iteration No: 10 started. Evaluating function at random point.
# [0.008679147174590262, 14, 45, 0.163515944581681, 0.5723194391834011]
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 2.0066
# Function value obtained: 0.9820
# Current minimum: 0.9811
# Iteration No: 11 started. Searching for the next optimal point.
# [0.001, 120, 50, 0.9523486628856703, 1.0]
#
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 6.1615
# Function value obtained: 0.9822
# Current minimum: 0.9811
# Iteration No: 12 started. Searching for the next optimal point.
# [0.0028395412989792573, 63, 41, 1.0, 0.7909889784224314]
#
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 3.7697
# Function value obtained: 0.9799
# Current minimum: 0.9799
# Iteration No: 13 started. Searching for the next optimal point.
# [0.0024508997433300185, 128, 13, 0.05, 0.1]
#
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 2.3507
# Function value obtained: 0.9836
# Current minimum: 0.9799
# Iteration No: 14 started. Searching for the next optimal point.
# [0.004841339711304471, 2, 50, 0.05, 1.0]
#
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 1.5269
# Function value obtained: 0.9834
# Current minimum: 0.9799
# Iteration No: 15 started. Searching for the next optimal point.
# [0.00846596149873665, 128, 45, 1.0, 0.1]
#
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 5.1562
# Function value obtained: 0.9846
# Current minimum: 0.9799
# Iteration No: 16 started. Searching for the next optimal point.
# [0.001, 2, 50, 1.0, 0.1]
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 1.2386
# Function value obtained: 0.9858
# Current minimum: 0.9799
# Iteration No: 17 started. Searching for the next optimal point.
# [0.001, 82, 45, 0.8454772675350539, 0.5486193483237857]
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 5.0558
# Function value obtained: 0.9845
# Current minimum: 0.9799
# Iteration No: 18 started. Searching for the next optimal point.
# [0.0019197986823657556, 47, 8, 0.737533089866813, 1.0]
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 3.3400
# Function value obtained: 0.9790
# Current minimum: 0.9790
# Iteration No: 19 started. Searching for the next optimal point.
# [0.05094233665606966, 116, 25, 0.5062025607916918, 0.1]
#
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 4.5110
# Function value obtained: 0.9890
# Current minimum: 0.9790
# Iteration No: 20 started. Searching for the next optimal point.
# [0.0016277170436171152, 2, 4, 0.5923868258515393, 0.3188330767149423]
#
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 1.2447
# Function value obtained: 0.9858
# Current minimum: 0.9790
# Iteration No: 21 started. Searching for the next optimal point.
# [0.005858921412878751, 29, 4, 0.6850887250416248, 0.30925365959748735]
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 2.7523
# Function value obtained: 0.9832
# Current minimum: 0.9790
# Iteration No: 22 started. Searching for the next optimal point.
# [0.004763827128833514, 65, 1, 0.05, 0.7871250752065202]
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 4.4667
# Function value obtained: 1.0156
# Current minimum: 0.9790
# Iteration No: 23 started. Searching for the next optimal point.
# [0.001, 6, 19, 1.0, 1.0]
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 1.6934
# Function value obtained: 0.9844
# Current minimum: 0.9790
# Iteration No: 24 started. Searching for the next optimal point.
# [0.0035831907677537646, 2, 34, 1.0, 0.3315180388247153]
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 1.4551
# Function value obtained: 0.9859
# Current minimum: 0.9790
# Iteration No: 25 started. Searching for the next optimal point.
# [0.1, 37, 50, 0.18988266321769398, 0.1]
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 2.5302
# Function value obtained: 0.9865
# Current minimum: 0.9790
# Iteration No: 26 started. Searching for the next optimal point.
# [0.01125536192936308, 118, 1, 0.6346138009189449, 0.1]
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 5.3756
# Function value obtained: 0.9884
# Current minimum: 0.9790
# Iteration No: 27 started. Searching for the next optimal point.
# [0.0025287792395519283, 70, 30, 0.5541430635772692, 1.0]
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 4.3294
# Function value obtained: 0.9800
# Current minimum: 0.9790
# Iteration No: 28 started. Searching for the next optimal point.
# [0.026762969339703617, 114, 50, 0.4155656680099436, 0.2740608273631132]
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 3.6084
# Function value obtained: 0.9854
# Current minimum: 0.9790
# Iteration No: 29 started. Searching for the next optimal point.
# [0.001, 123, 1, 0.5141941122362003, 1.0]
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 7.6495
# Function value obtained: 1.0089
# Current minimum: 0.9790
# Iteration No: 30 started. Searching for the next optimal point.
# [0.002927033391377435, 2, 50, 0.43423857473847277, 0.7010317389827275]
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 1.7553
# Function value obtained: 0.9853
# Current minimum: 0.9790
# Iteration No: 31 started. Searching for the next optimal point.
# [0.001, 2, 1, 1.0, 0.1]
#
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 1.7753
# Function value obtained: 0.9858
# Current minimum: 0.9790
# Iteration No: 32 started. Searching for the next optimal point.
# [0.0018541293679565848, 2, 35, 1.0, 1.0]
#
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 1.6935
# Function value obtained: 0.9850
# Current minimum: 0.9790
# Iteration No: 33 started. Searching for the next optimal point.
# [0.004672920254878985, 128, 50, 0.39456393419052993, 0.5732122245340752]
#
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 4.6536
# Function value obtained: 0.9818
# Current minimum: 0.9790
# Iteration No: 34 started. Searching for the next optimal point.
# [0.001, 128, 50, 0.093017739939671, 0.1]
#
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 2.7935
# Function value obtained: 0.9850
# Current minimum: 0.9790
# Iteration No: 35 started. Searching for the next optimal point.
# [0.0023918534434782977, 128, 17, 1.0, 1.0]
#
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 6.2174
# Function value obtained: 0.9773
# Current minimum: 0.9773
# Iteration No: 36 started. Searching for the next optimal point.
# [0.00742711542759363, 128, 20, 0.05, 0.15196865016072325]
#
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 2.5133
# Function value obtained: 0.9834
# Current minimum: 0.9773
# Iteration No: 37 started. Searching for the next optimal point.
# [0.001, 128, 25, 0.05, 0.1]
#
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 2.4285
# Function value obtained: 0.9849
# Current minimum: 0.9773
# Iteration No: 38 started. Searching for the next optimal point.
# [0.00373346312188877, 61, 1, 0.13203670038006304, 0.1]
#
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 3.8916
# Function value obtained: 0.9836
# Current minimum: 0.9773
# Iteration No: 39 started. Searching for the next optimal point.
# [0.025302133773911738, 126, 50, 0.28619049162778026, 0.1]
#
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 3.3421
# Function value obtained: 0.9850
# Current minimum: 0.9773
# Iteration No: 40 started. Searching for the next optimal point.
# [0.01858230490646337, 67, 50, 0.8576748795869774, 1.0]
#
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 4.9288
# Function value obtained: 0.9927
# Current minimum: 0.9773
# Iteration No: 41 started. Searching for the next optimal point.
# [0.1, 12, 50, 0.2778073333117798, 0.4865860913562402]
#
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 2.8703
# Function value obtained: 1.0100
# Current minimum: 0.9773
# Iteration No: 42 started. Searching for the next optimal point.
# [0.002619155612525873, 2, 17, 0.3069592236210217, 1.0]
#
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 1.8979
# Function value obtained: 0.9851
# Current minimum: 0.9773
# Iteration No: 43 started. Searching for the next optimal point.
# [0.001, 113, 23, 1.0, 0.44428095126550604]
#
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 6.1554
# Function value obtained: 0.9845
# Current minimum: 0.9773
# Iteration No: 44 started. Searching for the next optimal point.
# [0.0021569863867032697, 128, 25, 1.0, 0.8221626897601578]
#
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 6.0428
# Function value obtained: 0.9819
# Current minimum: 0.9773
# Iteration No: 45 started. Searching for the next optimal point.
# [0.003121383543392244, 54, 50, 0.7909687194812688, 0.10963198773701273]
#
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 3.6123
# Function value obtained: 0.9839
# Current minimum: 0.9773
# Iteration No: 46 started. Searching for the next optimal point.
# [0.07164738721757032, 63, 3, 0.831661627003546, 0.10576100505580767]
#
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 4.0552
# Function value obtained: 0.9942
# Current minimum: 0.9773
# Iteration No: 47 started. Searching for the next optimal point.
# [0.008497317843835363, 128, 50, 0.5526227777250771, 0.3555248748228065]
#
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 4.1199
# Function value obtained: 0.9839
# Current minimum: 0.9773
# Iteration No: 48 started. Searching for the next optimal point.
# [0.001030237592149002, 72, 50, 0.12361801928077674, 0.3555212072257311]
#
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 2.7833
# Function value obtained: 0.9849
# Current minimum: 0.9773
# Iteration No: 49 started. Searching for the next optimal point.
# [0.010874787285198343, 114, 50, 0.5371497596553406, 0.7282674181887567]
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 5.2699
# Function value obtained: 0.9849
# Current minimum: 0.9773
# Iteration No: 50 started. Searching for the next optimal point.
# [0.001002214117743197, 97, 31, 0.4383640683959667, 0.759023844285829]
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 6.0279
# Function value obtained: 0.9828
# Current minimum: 0.9773

# %%
#[0.0023918534434782977, 128, 17, 1.0, 1.0] >> 0.9773

learning_rate = 0.0023918534434782977
num_leaves = 128
min_child_samples = 17
subsample = 1.0
colsample_bytree = 1.0


feat_columns = ['Gold_mean', 'Mean_Price_Margin_ratio', 'month_cos', 'Current_Mean_Price_Dollar_mean_ratio']


mdl = LGBMRegressor(learning_rate=learning_rate, num_leaves=num_leaves, min_child_samples=min_child_samples,
                    subsample=subsample, colsample_bytree=colsample_bytree, random_state=0, subsample_freq=1, 
                     n_estimators=500, n_jobs=-1)

mdl.fit(Xtr[feat_columns], ytr)
p = mdl.predict(Xval[feat_columns])

p_final = Xval['Current_Mean_Price'] + p
yval_final = Xval['Current_Mean_Price'] + yval

np.sqrt(mean_squared_log_error(yval_final, p_final)) * 100
# Out:
# 0.9773431227963586
